# %% [markdown]
# # Write some markdown to explain that this notebook will be mainly used for the capstone project.

# %% [markdown]
# This notebook will be used to complete tasks/assignments for IBM Datascience Capstone course

# %% [markdown]
# # Main Code

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
